# %%
print("hello world")
# Out:
# hello world

# %%
help()
# Out:
# Welcome to Python 3.6's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at http://docs.python.org/3.6/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help>
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('D:/Vit/Semester_5/MachineLearning/Lab/pima-indians-diabetes-database/diabetes.csv', na_values=['NA'])

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            1       89             66             23       94  28.1
# 2            5      116             74              0        0  25.6
# 3           10      115              0              0        0  35.3
# 4            4      110             92              0        0  37.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.351   31        0
# 1                     0.167   21        0
# 2                     0.201   30        0
# 3                     0.134   29        0
# 4                     0.191   30        0

# %%
diabetes.head(150)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              1       85             66             29        0  26.6
# 1              1       89             66             23       94  28.1
# 2              5      116             74              0        0  25.6
# 3             10      115              0              0        0  35.3
# 4              4      110             92              0        0  37.6
# 5             10      139             80              0        0  27.1
# 6              1      103             30             38       83  43.3
# 7              3      126             88             41      235  39.3
# 8              8       99             84              0        0  35.4
# 9              1       97             66             15      140  23.2
# 10            13      145             82             19      110  22.2
# 11             5      117             92              0        0  34.1
# 12             5      109             75             26        0  36.0
# 13             3       88             58             11       54  24.8
# 14             6       92             92              0        0  19.9
# 15            10      122             78             31        0  27.6
# 16             4      103             60             33      192  24.0
# 17            11      138             76              0        0  33.2
# 18             3      180             64             25       70  34.0
# 19             7      133             84              0        0  40.2
# 20             7      106             92             18        0  22.7
# 21             7      159             64              0        0  27.4
# 22             1      146             56              0        0  29.7
# 23             2       71             70             27        0  28.0
# 24             7      105              0              0        0   0.0
# 25             1      103             80             11       82  19.4
# 26             1      101             50             15       36  24.2
# 27             5       88             66             21       23  24.4
# 28             7      150             66             42      342  34.7
# 29             1       73             50             10        0  23.0
# ..           ...      ...            ...            ...      ...   ...
# 120            4      141             74              0        0  27.6
# 121            3      111             62              0        0  22.6
# 122            9      123             70             44       94  33.1
# 123            8       85             55             20        0  24.4
# 124            1      105             58              0        0  24.3
# 125            0      113             80             16        0  31.0
# 126            1      138             82              0        0  40.1
# 127            0      108             68             20        0  27.3
# 128            2       99             70             16       44  20.4
# 129            6      103             72             32      190  37.7
# 130            5      111             72             28        0  23.9
# 131            1       96             64             27       87  33.2
# 132            2       81             60             22        0  27.7
# 133            0      147             85             54        0  42.8
# 134            7      179             95             31        0  34.2
# 135            6      125             68             30      120  30.0
# 136            7      119              0              0        0  25.2
# 137            7      142             60             33      190  28.8
# 138            1      100             66             15       56  23.6
# 139            1       87             78             27       32  34.6
# 140            0      101             76              0        0  35.7
# 141            4      197             70             39      744  36.7
# 142            0      117             80             31       53  45.2
# 143            1       79             80             25       37  25.4
# 144            4      122             68              0        0  35.0
# 145            3       74             68             28       45  29.7
# 146            0      104             76              0        0  18.4
# 147            1       91             64             24        0  29.2
# 148            4       91             70             32       88  33.1
# 149            2      146             76             35      194  38.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.351   31        0
# 1                       0.167   21        0
# 2                       0.201   30        0
# 3                       0.134   29        0
# 4                       0.191   30        0
# 5                       1.441   57        0
# 6                       0.183   33        0
# 7                       0.704   27        0
# 8                       0.388   50        0
# 9                       0.487   22        0
# 10                      0.245   57        0
# 11                      0.337   38        0
# 12                      0.546   60        0
# 13                      0.267   22        0
# 14                      0.188   28        0
# 15                      0.512   45        0
# 16                      0.966   33        0
# 17                      0.420   35        0
# 18                      0.271   26        0
# 19                      0.696   37        0
# 20                      0.235   48        0
# 21                      0.294   40        0
# 22                      0.564   29        0
# 23                      0.586   22        0
# 24                      0.305   24        0
# 25                      0.491   22        0
# 26                      0.526   26        0
# 27                      0.342   30        0
# 28                      0.718   42        0
# 29                      0.248   21        0
# ..                        ...  ...      ...
# 120                     0.244   40        0
# 121                     0.142   21        0
# 122                     0.374   40        0
# 123                     0.136   42        0
# 124                     0.187   21        0
# 125                     0.874   21        0
# 126                     0.236   28        0
# 127                     0.787   32        0
# 128                     0.235   27        0
# 129                     0.324   55        0
# 130                     0.407   27        0
# 131                     0.289   21        0
# 132                     0.290   25        0
# 133                     0.375   24        0
# 134                     0.164   60        0
# 135                     0.464   32        0
# 136                     0.209   37        0
# 137                     0.687   61        0
# 138                     0.666   26        0
# 139                     0.101   22        0
# 140                     0.198   26        0
# 141                     2.329   31        0
# 142                     0.089   24        0
# 143                     0.583   22        0
# 144                     0.394   29        0
# 145                     0.293   23        0
# 146                     0.582   27        0
# 147                     0.192   21        0
# 148                     0.446   22        0
# 149                     0.329   29        0
#
# [150 rows x 9 columns]

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# %matplotlib inline

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb

# %%
sb.pairplot(diabetes.dropna(), hue='Outcome', palette="husl")

# %%
diabetes.loc[diabetes['Outcome']== 2,'Outcome'] = 1

# %%
diabetes['Outcome'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
diabetes = diabetes.loc[(diabetes['Outcome'] != 0) & (diabetes['Pregnancies'] >= 10)]

# %%
diabetes.loc[diabetes['Outcome'] == 1, 'Pregnancies'].hist()

# %%
diabetes = pd.read_csv('D:/Vit/Semester_5/MachineLearning/Lab/pima-indians-diabetes-database/diabetes.csv', na_values=['NA'])

# %%
diabetes.loc[(diabetes['Outcome']==0) & (diabetes['Pregnancies'] <10) ]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              1       85             66             29        0  26.6
# 1              1       89             66             23       94  28.1
# 2              5      116             74              0        0  25.6
# 4              4      110             92              0        0  37.6
# 6              1      103             30             38       83  43.3
# 7              3      126             88             41      235  39.3
# 8              8       99             84              0        0  35.4
# 9              1       97             66             15      140  23.2
# 11             5      117             92              0        0  34.1
# 12             5      109             75             26        0  36.0
# 13             3       88             58             11       54  24.8
# 14             6       92             92              0        0  19.9
# 16             4      103             60             33      192  24.0
# 18             3      180             64             25       70  34.0
# 19             7      133             84              0        0  40.2
# 20             7      106             92             18        0  22.7
# 21             7      159             64              0        0  27.4
# 22             1      146             56              0        0  29.7
# 23             2       71             70             27        0  28.0
# 24             7      105              0              0        0   0.0
# 25             1      103             80             11       82  19.4
# 26             1      101             50             15       36  24.2
# 27             5       88             66             21       23  24.4
# 28             7      150             66             42      342  34.7
# 29             1       73             50             10        0  23.0
# 30             0      100             88             60      110  46.8
# 31             0      146             82              0        0  40.5
# 32             0      105             64             41      142  41.5
# 33             2       84              0              0        0   0.0
# 34             5       44             62              0        0  25.0
# ..           ...      ...            ...            ...      ...   ...
# 466            0      134             58             20      291  26.4
# 467            3      102             74              0        0  29.5
# 469            1      108             60             46      178  35.5
# 470            4       83             86             19        0  29.3
# 471            1      114             66             36      200  38.1
# 472            5      117             86             30      105  39.1
# 473            1      111             94              0        0  32.8
# 474            4      112             78             40        0  39.4
# 475            1      116             78             29      180  36.1
# 476            0      141             84             26        0  32.4
# 477            2      175             88              0        0  22.9
# 478            2       92             52              0        0  30.1
# 479            2      106             56             27      165  29.0
# 480            2      105             75              0        0  23.3
# 481            4       95             60             32        0  35.4
# 482            0      126             86             27      120  27.4
# 483            8       65             72             23        0  32.0
# 484            2       99             60             17      160  36.6
# 485            3      102             44             20       94  30.8
# 486            1      109             58             18      116  28.5
# 489            1       81             74             41       57  46.3
# 490            1      121             78             39       74  39.0
# 491            3      108             62             24        0  26.0
# 492            7      137             90             41        0  32.0
# 493            1      106             76              0        0  37.5
# 494            2       88             58             26       16  28.4
# 495            9       89             62              0        0  22.5
# 497            2      122             70             27        0  36.8
# 498            5      121             72             23      112  26.2
# 499            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.351   31        0
# 1                       0.167   21        0
# 2                       0.201   30        0
# 4                       0.191   30        0
# 6                       0.183   33        0
# 7                       0.704   27        0
# 8                       0.388   50        0
# 9                       0.487   22        0
# 11                      0.337   38        0
# 12                      0.546   60        0
# 13                      0.267   22        0
# 14                      0.188   28        0
# 16                      0.966   33        0
# 18                      0.271   26        0
# 19                      0.696   37        0
# 20                      0.235   48        0
# 21                      0.294   40        0
# 22                      0.564   29        0
# 23                      0.586   22        0
# 24                      0.305   24        0
# 25                      0.491   22        0
# 26                      0.526   26        0
# 27                      0.342   30        0
# 28                      0.718   42        0
# 29                      0.248   21        0
# 30                      0.962   31        0
# 31                      1.781   44        0
# 32                      0.173   22        0
# 33                      0.304   21        0
# 34                      0.587   36        0
# ..                        ...  ...      ...
# 466                     0.352   21        0
# 467                     0.121   32        0
# 469                     0.415   24        0
# 470                     0.317   34        0
# 471                     0.289   21        0
# 472                     0.251   42        0
# 473                     0.265   45        0
# 474                     0.236   38        0
# 475                     0.496   25        0
# 476                     0.433   22        0
# 477                     0.326   22        0
# 478                     0.141   22        0
# 479                     0.426   22        0
# 480                     0.560   53        0
# 481                     0.284   28        0
# 482                     0.515   21        0
# 483                     0.600   42        0
# 484                     0.453   21        0
# 485                     0.400   26        0
# 486                     0.219   22        0
# 489                     1.096   32        0
# 490                     0.261   28        0
# 491                     0.223   25        0
# 492                     0.391   39        0
# 493                     0.197   26        0
# 494                     0.766   22        0
# 495                     0.142   33        0
# 497                     0.340   27        0
# 498                     0.245   30        0
# 499                     0.315   23        0
#
# [472 rows x 9 columns]

# %%
diabetes.loc[diabetes['Outcome'] == 0, 'Glucose'].hist()

# %%
diabetes.loc[diabetes['Outcome']==1, 'Glucose'].hist()

# %%
truediabetes= diabetes.loc[diabetes['Outcome']==1]

# %%
truediabetes.mean()
# Out:
# Pregnancies                   4.865672
# Glucose                     141.257463
# BloodPressure                70.824627
# SkinThickness                22.164179
# Insulin                     100.335821
# BMI                          35.142537
# DiabetesPedigreeFunction      0.550500
# Age                          37.067164
# Outcome                       1.000000
# dtype: float64

# %%
falsediabetes= diabetes.loc[diabetes['Outcome']==0]

# %%
falsediabetes.mean()
# Out:
# Pregnancies                   3.298000
# Glucose                     109.980000
# BloodPressure                68.184000
# SkinThickness                19.664000
# Insulin                      68.792000
# BMI                          30.304200
# DiabetesPedigreeFunction      0.429734
# Age                          31.190000
# Outcome                       0.000000
# dtype: float64

# %%
diabetes.loc[(diabetes['Glucose'].isnull()) |
             (diabetes['Insulin'].isnull()) |
            (diabetes['BloodPressure'].isnull()) |
            (diabetes['Age'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
diabetes.loc[(diabetes['Outcome']==0,'SkinThickness')]
# Out:
# 7      19.664
# 12     19.664
# 28     19.000
# 34     31.000
# 36     19.664
# 86     54.000
# 246    19.664
# 274    19.664
# 281    28.000
# 327    19.664
# 333    19.664
# 358    40.000
# 436    33.000
# 464    19.664
# 505    19.664
# 518    19.664
# 558    40.000
# 559    19.664
# 578    19.664
# 582    17.000
# 634    19.664
# 658    19.664
# 660    19.664
# 672    23.000
# 717    18.000
# 744    37.000
# 745    33.000
# 763    48.000
# Name: SkinThickness, dtype: float64

# %%
averageSkinThickness=diabetes.loc[(diabetes['Outcome']==0,'SkinThickness')].mean()
diabetes.loc[diabetes['SkinThickness']==0,'SkinThickness'] = averageSkinThickness

# %%
diabetes.loc[(diabetes['Outcome'] == 1) &
              (diabetes['SkinThickness'] == averageSkinThickness)]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
clean_data=pd.read_csv('D:/Vit/Semester_5/MachineLearning/Lab/pima-indians-diabetes-database/diabetes.csv')

# %%
clean_data.loc[clean_data['Outcome']== 2,'Outcome'] = 1
averageBloodPressure=clean_data.loc[(clean_data['Outcome']==0,'BloodPressure')].mean()
clean_data.loc[clean_data['BloodPressure']==0,'BloodPressure'] = averageBloodPressure
averageSkinThickness=clean_data.loc[(clean_data['Outcome']==0,'SkinThickness')].mean()
clean_data.loc[clean_data['SkinThickness']==0,'SkinThickness'] = averageSkinThickness
averageInsulin=clean_data.loc[(clean_data['Outcome']==0,'Insulin')].mean()
clean_data.loc[clean_data['Insulin']==0,'Insulin'] = averageInsulin
averageBMI=clean_data.loc[(clean_data['Outcome']==0,'BMI')].mean()
clean_data.loc[clean_data['BMI']==0,'BMI'] = averageBMI
averageBloodPressure=clean_data.loc[(clean_data['Outcome']==1,'BloodPressure')].mean()
clean_data.loc[clean_data['BloodPressure']==0,'BloodPressure'] = averageBloodPressure
averageSkinThickness=clean_data.loc[(clean_data['Outcome']==1,'SkinThickness')].mean()
clean_data.loc[clean_data['SkinThickness']==0,'SkinThickness'] = averageSkinThickness
averageInsulin=clean_data.loc[(clean_data['Outcome']==1,'Insulin')].mean()
clean_data.loc[clean_data['Insulin']==0,'Insulin'] = averageInsulin
averageBMI=clean_data.loc[(clean_data['Outcome']==1,'BMI')].mean()
clean_data.loc[clean_data['BMI']==0,'BMI'] = averageBMI

# %%
sb.pairplot(clean_data,hue='Outcome')

# %%
clean_data.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                72.212813
# SkinThickness                26.348604
# Insulin                     113.299750
# BMI                          32.426623
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
clean_data.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      68.7920
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
clean_data.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0         19.664   68.792  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
plt.figure(figsize=(20, 20))

for column_index, column in enumerate(clean_data.columns):
    if column == 'Outcome':
        continue
    plt.subplot(4, 4, column_index + 1)
    sb.violinplot(x='Outcome', y=column, data=clean_data)

# %%
plt.figure(figsize=(20,20))

for column_index, column in enumerate(clean_data.columns):
    if column == 'Outcome':
        continue
    plt.subplot(4, 4, column_index + 1)
    sb.boxplot(x='Outcome', y=column, data=clean_data)
